# %%
import pandas as pd

df_model2 = pd.read_csv('df_limpio_1y2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pandas as pd
# ----> 3 df_model2 = pd.read_csv('df_limpio_1y2.csv')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_limpio_1y2.csv'

# %%
columnas_a_eliminar = [
    'incident_state_Closed',
    'contact_type_Self service',
    'category_Category 4',
    'subcategory_Subcategory 192',
    'subcategory_Subcategory 282',
    'impact_3 - Low',
    'urgency_3 - Low',
    'priority_4 - Low'  
]


df_model2.drop(columnas_a_eliminar, axis=1)
# Out:
#         active  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 0         True                   0             0              0      True
# 1         True                   0             0              2      True
# 2         True                   0             0              3      True
# 3        False                   0             0              4      True
# 4         True                   0             0              0      True
# ...        ...                 ...           ...            ...       ...
# 141707   False                   1             0              4      True
# 141708    True                   0             0              0      True
# 141709    True                   1             0              1      True
# 141710    True                   1             0              2      True
# 141711   False                   1             0              3      True
#
#         knowledge  u_priority_confirmation  incident_state_-100  \
# 0            True                    False                False
# 1            True                    False                False
# 2            True                    False                False
# 3            True                    False                False
# 4            True                    False                False
# ...           ...                      ...                  ...
# 141707      False                     True                False
# 141708      False                    False                False
# 141709      False                    False                False
# 141710      False                     True                False
# 141711      False                     True                False
#
#         incident_state_Active  incident_state_Awaiting Evidence  ...  \
# 0                       False                             False  ...
# 1                       False                             False  ...
# 2                       False                             False  ...
# 3                       False                             False  ...
# 4                       False                             False  ...
# ...                       ...                               ...  ...
# 141707                  False                             False  ...
# 141708                   True                             False  ...
# 141709                   True                             False  ...
# 141710                  False                             False  ...
# 141711                  False                             False  ...
#
#         subcategory_Subcategory 99  impact_1 - High  impact_2 - Medium  \
# 0                            False            False               True
# 1                            False            False               True
# 2                            False            False               True
# 3                            False            False               True
# 4                            False            False               True
# ...                            ...              ...                ...
# 141707                       False            False               True
# 141708                       False            False               True
# 141709                       False            False               True
# 141710                       False            False               True
# 141711                       False            False               True
#
#         urgency_1 - High  urgency_3 - Low  priority_1 - Critical  \
# 0                  False            False                  False
# 1                  False            False                  False
# 2                  False            False                  False
# 3                  False            False                  False
# 4                  False            False                  False
# ...                  ...              ...                    ...
# 141707             False            False                  False
# 141708             False            False                  False
# 141709             False            False                  False
# 141710             False            False                  False
# 141711             False            False                  False
#
#         priority_2 - High  priority_4 - Low  notify_Do Not Notify  \
# 0                   False             False                  True
# 1                   False             False                  True
# 2                   False             False                  True
# 3                   False             False                  True
# 4                   False             False                  True
# ...                   ...               ...                   ...
# 141707              False             False                  True
# 141708              False             False                  True
# 141709              False             False                  True
# 141710              False             False                  True
# 141711              False             False                  True
#
#         notify_Send Email
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 141707              False
# 141708              False
# 141709              False
# 141710              False
# 141711              False
#
# [141712 rows x 563 columns]

# %% [markdown]
# Se eliminaron ciertas variables que arrojaron una correlación alta.

# %%
from sklearn.metrics import accuracy_score, precision_score, log_loss, recall_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

y2 = df_model2["made_sla"]
x2 = df_model2.drop("made_sla", axis=1)
X_train, X_test, y_train, y_test = train_test_split(x2, y2, test_size=0.3, random_state=42)
model2 = LogisticRegression(max_iter=1000)
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred2))
print("Precision:", precision_score(y_test, y_pred2))
print("Log-loss (función de pérdida):", log_loss(y_test, y_pred2))
print("Recall:", recall_score(y_test, y_pred2))
# Out:
# Accuracy: 0.9697746624641295
# Precision: 0.9778258921905331
# Log-loss (función de pérdida): 1.0894315897119902
# Recall: 0.9900718155474361

# %% [markdown]
# Como las métricas nos dan exactamente lo mismo (teniendo en cuenta la misma cantidad de decimales), concluimos que no influye en nada quitar o dejar las variables encontradas con autocorrelación, por lo que tampoco se graficará la función de pérdida, pues sería casi idéntica a la del modelo #1. Nótese que también se cambiaron las variables y las métricas tampoco cambian.

# %%
df_model2_1 = pd.read_csv('df_limpio_1y2.csv')

columnas_a_eliminar2 = [
    'active',
    'contact_type_Phone',
    'category_Category 35',
    'category_Category 62',
    'subcategory_Subcategory 28',
    'impact_2 - Medium',
    'urgency_2 - Medium',
    'priority_3 - Moderate'  
]

df_model2_1.drop(columnas_a_eliminar2, axis=1)

y3 = df_model2_1["made_sla"]
x3 = df_model2_1.drop("made_sla", axis=1)
X_train, X_test, y_train, y_test = train_test_split(x3, y3, test_size=0.3, random_state=42)
model2_1 = LogisticRegression(max_iter=1000)
model2_1.fit(X_train, y_train)
y_pred2_1 = model2_1.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred2_1))
print("Precision:", precision_score(y_test, y_pred2_1))
print("Log-loss (función de pérdida):", log_loss(y_test, y_pred2_1))
print("Recall:", recall_score(y_test, y_pred2_1))
# Out:
# Accuracy: 0.9697746624641295
# Precision: 0.9778258921905331
# Log-loss (función de pérdida): 1.0894315897119902
# Recall: 0.9900718155474361
